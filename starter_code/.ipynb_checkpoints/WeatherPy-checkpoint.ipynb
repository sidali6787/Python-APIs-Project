# %% [markdown]
# # WeatherPy
# ----
#  Analysis
# # While there is no strong relationship between latitude and wind speed, the cities with wind speeds over 15 mph increase when you move either direction away from the equator.
# # As you move closer to the equator max temperature increases. The northern hemisphere tends to have the colder cities as you move away from the equator.
# # There is no strong relationship between latitude and humidity. However, there is a strong band of cities that sit at 100%. Within that band, there is a cluster located at the equator.
# ![Screen%20Shot%202021-01-18%20at%205.41.49%20PM.png](attachment:Screen%20Shot%202021-01-18%20at%205.41.49%20PM.png)

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 616

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
rcd = 0
sets = 1
city_weather = []

print('Beginning Data Retrieval\n-----------------------------')

for city in cities:
    
    rcd += 1
    
    print(f'Processing Record {rcd} of Set {sets} | {city}')
    
    if rcd == 50:
        rcd = 0
        sets += 1
        
    url = f'https://api.openweathermap.org/data/2.5/weather?q={city}&appid={weather_api_key}&units=imperial'
    try:
        response = requests.get(url).json()
        city_weather.append({
            'city': city,
            'lat': response['coord']['lat'],
            'lon': response['coord']['lon'],
            'temp': response['main']['temp_max'],
            'humidity': response['main']['humidity'],
            'wind': response['wind']['speed'],
            'clouds': response['clouds']['all'],
            'country': response['sys']['country'],
            'date': response['dt']
        })
    except:
        print('City not found. Skipping...')
        pass

print('-----------------------------\nData Retrieval Complete\n-----------------------------')
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 2 of Set 1 | port alfred
# Processing Record 3 of Set 1 | bluff
# Processing Record 4 of Set 1 | lagunillas
# Processing Record 5 of Set 1 | maltahohe
# Processing Record 6 of Set 1 | albany
# Processing Record 7 of Set 1 | waddan
# Processing Record 8 of Set 1 | baley
# Processing Record 9 of Set 1 | tuktoyaktuk
# Processing Record 10 of Set 1 | mataura
# Processing Record 11 of Set 1 | kapaa
# Processing Record 12 of Set 1 | vaini
# Processing Record 13 of Set 1 | provideniya
# Processing Record 14 of Set 1 | sao joao da barra
# Processing Record 15 of Set 1 | yellowknife
# Processing Record 16 of Set 1 | gizo
# Processing Record 17 of Set 1 | rikitea
# Processing Record 18 of Set 1 | upernavik
# Processing Record 19 of Set 1 | urumqi
# Processing Record 20 of Set 1 | kuryk
# Processing Record 21 of Set 1 | hilo
# Processing Record 22 of Set 1 | anito
# Processing Record 23 of Set 1 | hermanus
# Processing Record 24 of Set 1 | hurricane
# Processing Record 25 of Set 1 | busselton
# Processing Record 26 of Set 1 | tiksi
# Processing Record 27 of Set 1 | ushuaia
# Processing Record 28 of Set 1 | acapulco
# Processing Record 29 of Set 1 | umm kaddadah
# Processing Record 30 of Set 1 | coquimbo
# Processing Record 31 of Set 1 | haines junction
# Processing Record 32 of Set 1 | pangody
# Processing Record 33 of Set 1 | barrow
# Processing Record 34 of Set 1 | havre-saint-pierre
# Processing Record 35 of Set 1 | marang
# Processing Record 36 of Set 1 | souillac
# Processing Record 37 of Set 1 | kahului
# Processing Record 38 of Set 1 | berbera
# Processing Record 39 of Set 1 | bengkulu
# Processing Record 40 of Set 1 | arraial do cabo
# Processing Record 41 of Set 1 | esperance
# Processing Record 42 of Set 1 | atuona
# Processing Record 43 of Set 1 | hithadhoo
# Processing Record 44 of Set 1 | coihaique
# Processing Record 45 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 46 of Set 1 | hobart
# Processing Record 47 of Set 1 | olinda
# Processing Record 48 of Set 1 | sibolga
# Processing Record 49 of Set 1 | bonoua
# Processing Record 50 of Set 1 | buraydah
# Processing Record 1 of Set 2 | karatuzskoye
# Processing Record 2 of Set 2 | lavrentiya
# Processing Record 3 of Set 2 | barra patuca
# Processing Record 4 of Set 2 | kologriv
# Processing Record 5 of Set 2 | ponta do sol
# Processing Record 6 of Set 2 | te anau
# Processing Record 7 of Set 2 | butaritari
# Processing Record 8 of Set 2 | dehloran
# Processing Record 9 of Set 2 | ternate
# Processing Record 10 of Set 2 | tahoua
# Processing Record 11 of Set 2 | victor harbor
# Processing Record 12 of Set 2 | sur
# Processing Record 13 of Set 2 | nileshwar
# Processing Record 14 of Set 2 | san patricio
# Processing Record 15 of Set 2 | puerto ayora
# Processing Record 16 of Set 2 | georgetown
# Processing Record 17 of Set 2 | hasaki
# Processing Record 18 of Set 2 | sao felix do xingu
# Processing Record 19 of Set 2 | hinton
# Processing Record 20 of Set 2 | dunedin
# Processing Record 21 of Set 2 | sioux lookout
# Processing Record 22 of Set 2 | egvekinot
# Processing Record 23 of Set 2 | benguela
# Processing Record 24 of Set 2 | bambous virieux
# Processing Record 25 of Set 2 | yar-sale
# Processing Record 26 of Set 2 | saint-philippe
# Processing Record 27 of Set 2 | almeirim
# Processing Record 28 of Set 2 | klaksvik
# Processing Record 29 of Set 2 | pisco
# Processing Record 30 of Set 2 | bredasdorp
# Processing Record 31 of Set 2 | cape town
# Processing Record 32 of Set 2 | punta arenas
# Processing Record 33 of Set 2 | madison
# Processing Record 34 of Set 2 | ribeira grande
# Processing Record 35 of Set 2 | ponta delgada
# Processing Record 36 of Set 2 | calama
# Processing Record 37 of Set 2 | longyearbyen
# Processing Record 38 of Set 2 | uwayl
# City not found. Skipping...
# Processing Record 39 of Set 2 | alta floresta
# Processing Record 40 of Set 2 | avarua
# Processing Record 41 of Set 2 | half moon bay
# Processing Record 42 of Set 2 | beaucaire
# Processing Record 43 of Set 2 | lebu
# Processing Record 44 of Set 2 | flinders
# Processing Record 45 of Set 2 | ilulissat
# Processing Record 46 of Set 2 | tarko-sale
# Processing Record 47 of Set 2 | puerto narino
# Processing Record 48 of Set 2 | yumen
# Processing Record 49 of Set 2 | bridlington
# Processing Record 50 of Set 2 | luanda
# Processing Record 1 of Set 3 | khatanga
# Processing Record 2 of Set 3 | nelson bay
# Processing Record 3 of Set 3 | labutta
# City not found. Skipping...
# Processing Record 4 of Set 3 | caborca
# Processing Record 5 of Set 3 | lompoc
# Processing Record 6 of Set 3 | loudi
# Processing Record 7 of Set 3 | strezhevoy
# Processing Record 8 of Set 3 | sorvag
# City not found. Skipping...
# Processing Record 9 of Set 3 | meyungs
# City not found. Skipping...
# Processing Record 10 of Set 3 | uglovskoye
# Processing Record 11 of Set 3 | batemans bay
# Processing Record 12 of Set 3 | russell
# Processing Record 13 of Set 3 | tiebissou
# Processing Record 14 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 15 of Set 3 | anastacio
# Processing Record 16 of Set 3 | saint george
# Processing Record 17 of Set 3 | north bend
# Processing Record 18 of Set 3 | margate
# Processing Record 19 of Set 3 | matara
# Processing Record 20 of Set 3 | east london
# Processing Record 21 of Set 3 | caucaguita
# Processing Record 22 of Set 3 | morelia
# Processing Record 23 of Set 3 | victoria
# Processing Record 24 of Set 3 | hunza
# City not found. Skipping...
# Processing Record 25 of Set 3 | narsaq
# Processing Record 26 of Set 3 | jomalig
# City not found. Skipping...
# Processing Record 27 of Set 3 | araouane
# Processing Record 28 of Set 3 | beringovskiy
# Processing Record 29 of Set 3 | vostok
# Processing Record 30 of Set 3 | saint anthony
# Processing Record 31 of Set 3 | krasnoselkup
# Processing Record 32 of Set 3 | portland
# Processing Record 33 of Set 3 | lincoln
# Processing Record 34 of Set 3 | fortuna
# Processing Record 35 of Set 3 | mount isa
# Processing Record 36 of Set 3 | dingle
# Processing Record 37 of Set 3 | chicama
# Processing Record 38 of Set 3 | tuatapere
# Processing Record 39 of Set 3 | berlevag
# Processing Record 40 of Set 3 | sabang
# Processing Record 41 of Set 3 | udachnyy
# Processing Record 42 of Set 3 | kasongo-lunda
# Processing Record 43 of Set 3 | tighina
# Processing Record 44 of Set 3 | kysyl-syr
# Processing Record 45 of Set 3 | susanville
# Processing Record 46 of Set 3 | bethel
# Processing Record 47 of Set 3 | nkhotakota
# Processing Record 48 of Set 3 | wanning
# Processing Record 49 of Set 3 | jamestown
# Processing Record 50 of Set 3 | schroeder
# Processing Record 1 of Set 4 | cidreira
# Processing Record 2 of Set 4 | itarema
# Processing Record 3 of Set 4 | palu
# Processing Record 4 of Set 4 | ishurdi
# Processing Record 5 of Set 4 | dikson
# Processing Record 6 of Set 4 | castro
# Processing Record 7 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 8 of Set 4 | kitgum
# Processing Record 9 of Set 4 | yatou
# Processing Record 10 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 11 of Set 4 | santa rosa
# Processing Record 12 of Set 4 | severnyy
# Processing Record 13 of Set 4 | storm lake
# Processing Record 14 of Set 4 | walvis bay
# Processing Record 15 of Set 4 | kintinku
# Processing Record 16 of Set 4 | phan rang
# City not found. Skipping...
# Processing Record 17 of Set 4 | luderitz
# Processing Record 18 of Set 4 | evensk
# Processing Record 19 of Set 4 | luangwa
# Processing Record 20 of Set 4 | manta
# Processing Record 21 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 22 of Set 4 | qaanaaq
# Processing Record 23 of Set 4 | saskylakh
# Processing Record 24 of Set 4 | cabo san lucas
# Processing Record 25 of Set 4 | vestmanna
# Processing Record 26 of Set 4 | mahebourg
# Processing Record 27 of Set 4 | pangkalanbuun
# Processing Record 28 of Set 4 | beroroha
# Processing Record 29 of Set 4 | tahta
# Processing Record 30 of Set 4 | talnakh
# Processing Record 31 of Set 4 | sorland
# Processing Record 32 of Set 4 | thompson
# Processing Record 33 of Set 4 | polson
# Processing Record 34 of Set 4 | le mars
# Processing Record 35 of Set 4 | kaduqli
# Processing Record 36 of Set 4 | grand gaube
# Processing Record 37 of Set 4 | lima
# Processing Record 38 of Set 4 | amahai
# Processing Record 39 of Set 4 | leningradskiy
# Processing Record 40 of Set 4 | port elizabeth
# Processing Record 41 of Set 4 | les cayes
# Processing Record 42 of Set 4 | bereda
# Processing Record 43 of Set 4 | mar del plata
# Processing Record 44 of Set 4 | arcos
# Processing Record 45 of Set 4 | nenjiang
# Processing Record 46 of Set 4 | parabel
# Processing Record 47 of Set 4 | raudeberg
# Processing Record 48 of Set 4 | new norfolk
# Processing Record 49 of Set 4 | japura
# Processing Record 50 of Set 4 | crib point
# Processing Record 1 of Set 5 | minsk
# Processing Record 2 of Set 5 | kaitangata
# Processing Record 3 of Set 5 | wahran
# City not found. Skipping...
# Processing Record 4 of Set 5 | myitkyina
# Processing Record 5 of Set 5 | opuwo
# Processing Record 6 of Set 5 | pevek
# Processing Record 7 of Set 5 | upata
# Processing Record 8 of Set 5 | mayumba
# Processing Record 9 of Set 5 | oktyabrskiy
# Processing Record 10 of Set 5 | chuy
# Processing Record 11 of Set 5 | faya
# Processing Record 12 of Set 5 | bairiki
# Processing Record 13 of Set 5 | lamar
# Processing Record 14 of Set 5 | carnarvon
# Processing Record 15 of Set 5 | zhangjiakou
# Processing Record 16 of Set 5 | tasiilaq
# Processing Record 17 of Set 5 | catamarca
# Processing Record 18 of Set 5 | anadyr
# Processing Record 19 of Set 5 | pilibanga
# Processing Record 20 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 21 of Set 5 | mariental
# Processing Record 22 of Set 5 | invermere
# Processing Record 23 of Set 5 | yaan
# Processing Record 24 of Set 5 | zalantun
# Processing Record 25 of Set 5 | miles city
# Processing Record 26 of Set 5 | katsuura
# Processing Record 27 of Set 5 | howard springs
# Processing Record 28 of Set 5 | tilichiki
# Processing Record 29 of Set 5 | lubango
# Processing Record 30 of Set 5 | beipiao
# Processing Record 31 of Set 5 | taltal
# Processing Record 32 of Set 5 | kazalinsk
# City not found. Skipping...
# Processing Record 33 of Set 5 | samarai
# Processing Record 34 of Set 5 | nerchinskiy zavod
# Processing Record 35 of Set 5 | northam
# Processing Record 36 of Set 5 | liwale
# Processing Record 37 of Set 5 | port lincoln
# Processing Record 38 of Set 5 | naron
# Processing Record 39 of Set 5 | pimentel
# Processing Record 40 of Set 5 | nanortalik
# Processing Record 41 of Set 5 | goderich
# Processing Record 42 of Set 5 | kropotkin
# Processing Record 43 of Set 5 | aketi
# Processing Record 44 of Set 5 | faanui
# Processing Record 45 of Set 5 | beaupre
# Processing Record 46 of Set 5 | padang
# Processing Record 47 of Set 5 | kodiak
# Processing Record 48 of Set 5 | alyangula
# Processing Record 49 of Set 5 | waingapu
# Processing Record 50 of Set 5 | kastornoye
# Processing Record 1 of Set 6 | jining
# Processing Record 2 of Set 6 | borovoy
# Processing Record 3 of Set 6 | kang
# Processing Record 4 of Set 6 | ugoofaaru
# Processing Record 5 of Set 6 | denpasar
# Processing Record 6 of Set 6 | felipe carrillo puerto
# Processing Record 7 of Set 6 | merauke
# Processing Record 8 of Set 6 | lacdayan
# Processing Record 9 of Set 6 | sao filipe
# Processing Record 10 of Set 6 | port hardy
# Processing Record 11 of Set 6 | palmerston
# Processing Record 12 of Set 6 | westport
# Processing Record 13 of Set 6 | mayo
# Processing Record 14 of Set 6 | pizarro
# Processing Record 15 of Set 6 | gangakher
# Processing Record 16 of Set 6 | yanan
# City not found. Skipping...
# Processing Record 17 of Set 6 | ambasamudram
# Processing Record 18 of Set 6 | deputatskiy
# Processing Record 19 of Set 6 | punta de piedra
# Processing Record 20 of Set 6 | aiquile
# Processing Record 21 of Set 6 | torbay
# Processing Record 22 of Set 6 | namatanai
# Processing Record 23 of Set 6 | tongliao
# Processing Record 24 of Set 6 | nkowakowa
# Processing Record 25 of Set 6 | abu dhabi
# Processing Record 26 of Set 6 | vila franca do campo
# Processing Record 27 of Set 6 | kasimov
# Processing Record 28 of Set 6 | suhbaatar
# Processing Record 29 of Set 6 | viedma
# Processing Record 30 of Set 6 | bubaque
# Processing Record 31 of Set 6 | shwebo
# Processing Record 32 of Set 6 | barentsburg
# City not found. Skipping...
# Processing Record 33 of Set 6 | cochrane
# Processing Record 34 of Set 6 | port blair
# Processing Record 35 of Set 6 | horsham
# Processing Record 36 of Set 6 | vicente guerrero
# Processing Record 37 of Set 6 | mount gambier
# Processing Record 38 of Set 6 | vila velha
# Processing Record 39 of Set 6 | orlik
# Processing Record 40 of Set 6 | constitucion
# Processing Record 41 of Set 6 | airai
# Processing Record 42 of Set 6 | korhogo
# Processing Record 43 of Set 6 | bud
# Processing Record 44 of Set 6 | chuncheng
# Processing Record 45 of Set 6 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 46 of Set 6 | san juan
# Processing Record 47 of Set 6 | sainte-marie
# Processing Record 48 of Set 6 | djenne
# Processing Record 49 of Set 6 | diebougou
# Processing Record 50 of Set 6 | carballo
# Processing Record 1 of Set 7 | norman wells
# Processing Record 2 of Set 7 | cherskiy
# Processing Record 3 of Set 7 | ancud
# Processing Record 4 of Set 7 | kerteh
# City not found. Skipping...
# Processing Record 5 of Set 7 | bognor regis
# Processing Record 6 of Set 7 | chumikan
# Processing Record 7 of Set 7 | guerrero negro
# Processing Record 8 of Set 7 | fuyu
# Processing Record 9 of Set 7 | panguna
# Processing Record 10 of Set 7 | malwan
# City not found. Skipping...
# Processing Record 11 of Set 7 | salalah
# Processing Record 12 of Set 7 | srednekolymsk
# Processing Record 13 of Set 7 | shingu
# Processing Record 14 of Set 7 | brunico
# Processing Record 15 of Set 7 | pryluky
# Processing Record 16 of Set 7 | new waterford
# Processing Record 17 of Set 7 | talara
# Processing Record 18 of Set 7 | nouadhibou
# Processing Record 19 of Set 7 | nuuk
# Processing Record 20 of Set 7 | lexington
# Processing Record 21 of Set 7 | bardiyah
# Processing Record 22 of Set 7 | touros

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
city_df = pd.DataFrame(city_weather)
city_df.to_csv('city_data.csv')
city_df.head()
# Out:
#           city      lat       lon   temp  humidity   wind  clouds country  \
# 0  port alfred -33.5906   26.8910  69.01        90   5.01      29      ZA
# 1        bluff -46.6000  168.3333  51.01        92   1.99     100      NZ
# 2   lagunillas  10.1301  -71.2595  84.09        60   7.76      78      VE
# 3    maltahohe -24.8333   16.9833  78.87        26  14.32      60      NA
# 4       albany  42.6001  -73.9662  37.99        67   9.64     100      US
#
#          date
# 0  1611001858
# 1  1611001858
# 2  1611001858
# 3  1611001859
# 4  1611001805

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
city_df.describe()
# Out:
#               lat         lon        temp    humidity        wind      clouds  \
# count  567.000000  567.000000  567.000000  567.000000  567.000000  567.000000
# mean    19.950961   20.340013   48.794797   71.726631    8.163175   52.419753
# std     33.143144   90.916556   34.237935   20.861339    5.635041   40.158170
# min    -54.800000 -179.166700  -52.530000   11.000000    0.470000    0.000000
# 25%     -6.923500  -63.137250   30.990000   62.000000    3.825000    5.000000
# 50%     22.566700   23.983300   59.580000   77.000000    7.000000   57.000000
# 75%     48.791750  106.156150   77.000000   86.000000   11.085000   95.000000
# max     78.218600  179.316700   93.580000  100.000000   32.120000  100.000000
#
#                date
# count  5.670000e+02
# mean   1.611002e+09
# std    6.903444e+01
# min    1.611002e+09
# 25%    1.611002e+09
# 50%    1.611002e+09
# 75%    1.611002e+09
# max    1.611002e+09

# %%
#  Get the indices of cities that have humidity over 100%.
# Humidity is not more than 100% in the above case!

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
city_df.plot(x='lat', y='temp',kind='scatter', edgecolor='black', linewidths=1, grid=True)
plt.title("City Latitude vs. Max Temperature (01/18/21)")
plt.show()

# %%
city_df.plot(x='lat', y='humidity',kind='scatter', edgecolor='black', linewidths=1, grid=True)
plt.title("City Latitude vs. Max Temperature (01/18/21)")
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
city_df.plot(x='lat', y='humidity',kind='scatter', edgecolor='black', linewidths=1, grid=True)
plt.title("City Latitude vs. humidity (01/18/21)")
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
city_df.plot(x='lat', y='clouds',kind='scatter', edgecolor='black', linewidths=1, grid=True)
plt.title("City Latitude vs. clouds (01/18/21)")
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
city_df.plot(x='lat', y='wind',kind='scatter', edgecolor='black', linewidths=1, grid=True)
plt.title("City Latitude vs. wind (01/18/21)")
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
north_hemisphere = (city_df.loc[city_df['lat']>0])
south_hemisphere = (city_df.loc[city_df['lat']<0])
city_df.describe()
# Out:
#               lat         lon        temp    humidity        wind      clouds  \
# count  567.000000  567.000000  567.000000  567.000000  567.000000  567.000000
# mean    19.950961   20.340013   48.794797   71.726631    8.163175   52.419753
# std     33.143144   90.916556   34.237935   20.861339    5.635041   40.158170
# min    -54.800000 -179.166700  -52.530000   11.000000    0.470000    0.000000
# 25%     -6.923500  -63.137250   30.990000   62.000000    3.825000    5.000000
# 50%     22.566700   23.983300   59.580000   77.000000    7.000000   57.000000
# 75%     48.791750  106.156150   77.000000   86.000000   11.085000   95.000000
# max     78.218600  179.316700   93.580000  100.000000   32.120000  100.000000
#
#                date
# count  5.670000e+02
# mean   1.611002e+09
# std    6.903444e+01
# min    1.611002e+09
# 25%    1.611002e+09
# 50%    1.611002e+09
# 75%    1.611002e+09
# max    1.611002e+09

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
(slope, intercept, rvalue, pvalue, stderr) = linregress(north_hemisphere["lat"],north_hemisphere["temp"])
regress_values = north_hemisphere["lat"] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(line_eq)
plt.scatter(north_hemisphere["lat"],north_hemisphere["temp"])
plt.plot(north_hemisphere["lat"],regress_values,"r-")
plt.annotate(line_eq,(10,-20),fontsize=15,color="red")
plt.title("Northern Hemisphere: Correlation of Latitude and Max Temperatures", y=1.02, fontsize=18);
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
print(f"The R value (i.e. Coefficient of Correlation) is: {rvalue}")
print(f"The R squared value (i.e. Coefficient of Determination) is: {rvalue**2}")
plt.show()
# Out:
# y = -1.48x + 94.71
# The R value (i.e. Coefficient of Correlation) is: -0.8327634194037015
# The R squared value (i.e. Coefficient of Determination) is: 0.6934949126969452

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
(slope, intercept, rvalue, pvalue, stderr) = linregress(south_hemisphere["lat"],south_hemisphere["temp"])
regress_values = south_hemisphere["lat"] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(line_eq)
plt.scatter(south_hemisphere["lat"],south_hemisphere["temp"])
plt.plot(south_hemisphere["lat"],regress_values,"r-")
plt.annotate(line_eq,(-25,60),fontsize=15,color="red")
plt.title("Southern Hemisphere: Correlation of Latitude and Max temperatures", y=1.02, fontsize=18);
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
print(f"The R value (i.e. Coefficient of Correlation) is: {rvalue}")
print(f"The R squared value (i.e. Coefficient of Determination) is: {rvalue**2}")
plt.show()
# Out:
# y = 0.4x + 82.27
# The R value (i.e. Coefficient of Correlation) is: 0.5712042858762354
# The R squared value (i.e. Coefficient of Determination) is: 0.32627433620338003

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
(slope, intercept, rvalue, pvalue, stderr) = linregress(north_hemisphere["lat"],north_hemisphere["humidity"])
regress_values = north_hemisphere["lat"] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(line_eq)
plt.scatter(north_hemisphere["lat"],north_hemisphere["humidity"])
plt.plot(north_hemisphere["lat"],regress_values,"r-")
plt.annotate(line_eq,(40,20),fontsize=15,color="red")
plt.title("Northern Hemisphere: Correlation of Latitude and Humidity (%)", y=1.02, fontsize=18);
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
print(f"The R value (i.e. Coefficient of Correlation) is: {rvalue}")
print(f"The R squared value (i.e. Coefficient of Determination) is: {rvalue**2}")
plt.show()
# Out:
# y = 0.4x + 54.72
# The R value (i.e. Coefficient of Correlation) is: 0.36692679819641755
# The R squared value (i.e. Coefficient of Determination) is: 0.13463527523467453

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
(slope, intercept, rvalue, pvalue, stderr) = linregress(south_hemisphere["lat"],south_hemisphere["humidity"])
regress_values = south_hemisphere["lat"] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(line_eq)
plt.scatter(south_hemisphere["lat"],south_hemisphere["humidity"])
plt.plot(south_hemisphere["lat"],regress_values,"r-")
plt.annotate(line_eq,(-25,60),fontsize=15,color="red")
plt.title("Southern Hemisphere: Correlation of Latitude and Humidity", y=1.02, fontsize=18);
plt.xlabel('Latitude')
plt.ylabel('Humidity')
print(f"The R value (i.e. Coefficient of Correlation) is: {rvalue}")
print(f"The R squared value (i.e. Coefficient of Determination) is: {rvalue**2}")
plt.show()
# Out:
# y = 0.35x + 81.47
# The R value (i.e. Coefficient of Correlation) is: 0.2482009592076922
# The R squared value (i.e. Coefficient of Determination) is: 0.061603716151618484

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
(slope, intercept, rvalue, pvalue, stderr) = linregress(north_hemisphere["lat"],north_hemisphere["clouds"])
regress_values = north_hemisphere["lat"] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(line_eq)
plt.scatter(north_hemisphere["lat"],north_hemisphere["clouds"])
plt.plot(north_hemisphere["lat"],regress_values,"r-")
plt.annotate(line_eq,(60,40),fontsize=15,color="red")
plt.title("Northern Hemisphere: Correlation of Latitude and Cloudiness %", y=1.02, fontsize=18);
plt.xlabel('Latitude')
plt.ylabel('Cloudiness %')
print(f"The R value (i.e. Coefficient of Correlation) is: {rvalue}")
print(f"The R squared value (i.e. Coefficient of Determination) is: {rvalue**2}")
plt.show()
# Out:
# y = 0.52x + 31.28
# The R value (i.e. Coefficient of Correlation) is: 0.2565208877705517
# The R squared value (i.e. Coefficient of Determination) is: 0.06580296586259199

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
(slope, intercept, rvalue, pvalue, stderr) = linregress(south_hemisphere["lat"],south_hemisphere["clouds"])
regress_values = south_hemisphere["lat"] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(line_eq)
plt.scatter(south_hemisphere["lat"],south_hemisphere["clouds"])
plt.plot(south_hemisphere["lat"],regress_values,"r-")
plt.annotate(line_eq,(-25,60),fontsize=15,color="red")
plt.title("Correlation of Latitude and Cloudiness % (Southern Hemisphere)", y=1.02, fontsize=18);
plt.xlabel('Latitude')
plt.ylabel('Humidity')
print(f"The R value (i.e. Coefficient of Correlation) is: {rvalue}")
print(f"The R squared value (i.e. Coefficient of Determination) is: {rvalue**2}")
plt.show()
# Out:
# y = 0.72x + 68.21
# The R value (i.e. Coefficient of Correlation) is: 0.24265194320256284
# The R squared value (i.e. Coefficient of Determination) is: 0.05887996553997978

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
(slope, intercept, rvalue, pvalue, stderr) = linregress(north_hemisphere["lat"],north_hemisphere["wind"])
regress_values = north_hemisphere["lat"] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(line_eq)
plt.scatter(north_hemisphere["lat"],north_hemisphere["wind"])
plt.plot(north_hemisphere["lat"],regress_values,"r-")
plt.annotate(line_eq,(5,30),fontsize=15,color="red")
plt.title("Northern Hemisphere: Correlation of Latitude and Wind (mph)", y=1.02, fontsize=18);
plt.xlabel('Latitude')
plt.ylabel('Wind (mhp)')
print(f"The R value (i.e. Coefficient of Correlation) is: {rvalue}")
print(f"The R squared value (i.e. Coefficient of Determination) is: {rvalue**2}")
plt.show()
# Out:
# y = 0.01x + 7.6
# The R value (i.e. Coefficient of Correlation) is: 0.04702682202885187
# The R squared value (i.e. Coefficient of Determination) is: 0.0022115219901333075

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
(slope, intercept, rvalue, pvalue, stderr) = linregress(south_hemisphere["lat"],south_hemisphere["wind"])
regress_values = south_hemisphere["lat"] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(line_eq)
plt.scatter(south_hemisphere["lat"],south_hemisphere["wind"])
plt.plot(south_hemisphere["lat"],regress_values,"r-")
plt.annotate(line_eq,(-25,25),fontsize=15,color="red")
plt.title("Southern Hemisphere: Correlation of Latitude and Wind Speed (mph)", y=1.02, fontsize=18);
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
print(f"The R value (i.e. Coefficient of Correlation) is: {rvalue}")
print(f"The R squared value (i.e. Coefficient of Determination) is: {rvalue**2}")
plt.show()
# Out:
# y = -0.08x + 6.61
# The R value (i.e. Coefficient of Correlation) is: -0.20437086753552422
# The R squared value (i.e. Coefficient of Determination) is: 0.04176745149722279
